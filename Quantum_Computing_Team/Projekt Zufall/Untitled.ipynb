# %%
from qiskit.circuit.library import HGate
from qiskit import QuantumCircuit
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService
from PIL import Image
import math


# Simulatoren
from qiskit_ibm_runtime.fake_provider import FakeAlmadenV2
from qiskit_aer import AerSimulator


# Quantencircuit erstellen
hadamard_gate = HGate()
circuit = QuantumCircuit(1)
circuit.append(hadamard_gate, [0])
circuit.measure_all()

# Quantencircuit anzeigen
circuit.draw("mpl")

# %%
# Festlegen des Simulators/Quantencomputers
backend = AerSimulator(method='extended_stabilizer')
 
# Convert to an ISA circuit
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)

# Anfrage schicken
job = backend.run(isa_circuit, shots = 100000, memory = True)

result = job.result()
memory = result.get_memory()
print(result)
# Out:
# Result(backend_name='aer_simulator_extended_stabilizer', backend_version='0.17.1', job_id='a3039813-d9aa-4f0e-ba2f-077f9a0e528b', success=True, results=[ExperimentResult(shots=100000, success=True, meas_level=2, data=ExperimentResultData(counts={'0x1': 50031, '0x0': 49969}, memory=['0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x1', '0x0', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x0', '0x0', '0x0', '0x0', '0x1', '0x0', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x1', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0', '0x0', '0x1', '0x0', '0x1', '0x1', '0x1', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x1', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x1', '0x0', '0x0', '0x1', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x1', '0x0', '0x1', '0x1', '0x1', '0x1', '0x0', '0x1', '0x0', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0', '0x1', '0x1', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0', '0x1', '0x1', '0x0', '0x1', '0x1', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x1', '0x1', '0x0', '0x1', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x1', '0x1', '0x0', '0x0', '0x1', '0x1', '0x1', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x0', '0x1', '0x1', '0x0', '0x1', '0x0', '0x0', '0x0', '0x1', '0x1', '0x0
line='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows(bytes_list)
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_17432\3882442045.py:8: DeprecationWarning: The "ibm_quantum" channel option is deprecated and will be sunset on 1 July. After this date, "ibm_cloud", "ibm_quantum_platform", and "local" will be the only valid channels. Open Plan users should migrate now.  All other users should review the migration guide (https://quantum.cloud.ibm.com/docs/migration-guides/classic-iqp-to-cloud-iqp)to learn when to migrate.
#   service = QiskitRuntimeService(
# ❌ Kritischer Fehler: '401 Client Error: Unauthorized for url: https://auth.quantum.ibm.com/api/users/loginWithToken. Login failed., Error code: 3446.'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(f"Job-Status: {job.status()}")
#
# NameError: name 'job' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 result = job.result()
#       2 counts = result.get_counts()  # Histogramm der Messergebnisse
#       3 print(counts)
#
# NameError: name 'job' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 from qiskit.visualization import plot_histogram
# ----> 2 plot_histogram(counts)
#
# NameError: name 'counts' is not defined

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting qiskit-ibm-provider
#   Downloading qiskit_ibm_provider-0.11.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: qiskit>=0.45.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from qiskit-ibm-provider) (2.1.0)
# Requirement already satisfied: requests>=2.19 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from qiskit-ibm-provider) (2.32.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from qiskit-ibm-provider) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibm-provider) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from qiskit-ibm-provider) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibm-provider) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.5.1 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibm-provider) (1.8.0)
# Collecting websockets>=10.0 (from qiskit-ibm-provider)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions>=4.3 in c:\programdata\anaconda3\lib\site-packages (from qiskit-ibm-provider) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibm-provider) (1.16.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from qiskit>=0.45.0->qiskit-ibm-provider) (0.16.0)
# Requirement already satisfied: scipy>=1.5 in c:\programdata\anaconda3\lib\site-packages (from qiskit>=0.45.0->qiskit-ibm-provider) (1.13.1)
# Requirement already satisfied: dill>=0.3 in c:\programdata\anaconda3\lib\site-packages (from qiskit>=0.45.0->qiskit-ibm-provider) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from qiskit>=0.45.0->qiskit-ibm-provider) (5.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-provider) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-provider) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibm-provider) (2025.6.15)
# Requirement already satisfied: cryptography>=1.3 in c:\programdata\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-provider) (43.0.0)
# Requirement already satisfied: pyspnego>=0.4.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-provider) (0.11.2)
# Requirement already satisfied: cffi>=1.12 in c:\programdata\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-provider) (1.17.1)
# Requirement already satisfied: sspilib>=0.1.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-provider) (0.3.1)
# Requirement already satisfied: pbr>=2.0.0 in c:\users\juanc\appdata\roaming\python\python312\site-packages (from stevedore>=3.0.0->qiskit>=0.45.0->qiskit-ibm-provider) (6.1.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-provider) (2.21)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from pbr>=2.0.0->stevedore>=3.0.0->qiskit>=0.45.0->qiskit-ibm-provider) (75.1.0)
# Downloading qiskit_ibm_provider-0.11.0-py3-none-any.whl (249 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Installing collected packages: websockets, qiskit-ibm-provider
# Successfully installed qiskit-ibm-provider-0.11.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script websockets.exe is installed in 'C:\Users\juanc\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
